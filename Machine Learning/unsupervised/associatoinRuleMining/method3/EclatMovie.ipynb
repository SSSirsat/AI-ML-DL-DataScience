# %% [markdown]
# # **Eclat for Movie Recomendation Analysis**

# %%
#!pip install apyori

# %%
import pandas as pd
import numpy as np
from apyori import apriori
import random

# %% [markdown]
# ## Preprocessing the data

# %%
url = 'https://raw.githubusercontent.com/furqoncreative/data-mining-eclat/master/movie_metadata.csv'
dataset=pd.read_csv(url)
dataset.fillna(value=0,axis=1,inplace=True)
dataset.head()
# Out:
#    color      director_name num_critic_for_reviews duration  \
# 0  Color      James Cameron                  723.0    178.0
# 1  Color     Gore Verbinski                  302.0    169.0
# 2  Color         Sam Mendes                  602.0    148.0
# 3  Color  Christopher Nolan                  813.0    164.0
# 4      0        Doug Walker                      0        0
#
#   director_facebook_likes actor_3_facebook_likes      actor_2_name  \
# 0                     0.0                  855.0  Joel David Moore
# 1                   563.0                 1000.0     Orlando Bloom
# 2                     0.0                  161.0      Rory Kinnear
# 3                 22000.0                23000.0    Christian Bale
# 4                   131.0                      0        Rob Walker
#
#   actor_1_facebook_likes        gross                           genres  ...  \
# 0                 1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                27000.0  448130642.0                  Action|Thriller  ...
# 4                  131.0            0                      Documentary  ...
#
#   num_user_for_reviews language country content_rating       budget  \
# 0               3054.0  English     USA          PG-13  237000000.0
# 1               1238.0  English     USA          PG-13  300000000.0
# 2                994.0  English      UK          PG-13  245000000.0
# 3               2701.0  English     USA          PG-13  250000000.0
# 4                    0        0       0              0            0
#
#   title_year actor_2_facebook_likes imdb_score aspect_ratio  \
# 0     2009.0                  936.0        7.9         1.78
# 1     2007.0                 5000.0        7.1         2.35
# 2     2015.0                  393.0        6.8         2.35
# 3     2012.0                23000.0        8.5         2.35
# 4          0                   12.0        7.1            0
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
dataset.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
dataset.shape
# Out:
# (5043, 28)

# %%
movieData=[]
for i in range(0,1000):
    movieData.append([str(dataset.values[i,j]) for j in range(0,28)])

# %%
movieData[:1]
# Out:
# [['Color',
#   'James Cameron',
#   '723.0',
#   '178.0',
#   '0.0',
#   '855.0',
#   'Joel David Moore',
#   '1000.0',
#   '760505847.0',
#   'Action|Adventure|Fantasy|Sci-Fi',
#   'CCH Pounder',
#   'Avatar\xa0',
#   '886204',
#   '4834',
#   'Wes Studi',
#   '0.0',
#   'avatar|future|marine|native|paraplegic',
#   'http://www.imdb.com/title/tt0499549/?ref_=fn_tt_tt_1',
#   '3054.0',
#   'English',
#   'USA',
#   'PG-13',
#   '237000000.0',
#   '2009.0',
#   '936.0',
#   '7.9',
#   '1.78',
#   '33000']]

# %%
def getNextMovie(s):
    for i in range(0,1000):
      if (movieData)[i][10] == s[10] or (movieData)[i][9] == s[1] or (movieData)[i][9] == s[9]:
        if movieData[i][11] != s[11]:
          return movieData[i]
        else:
          return random.choice(movieData)
      else: 
        return random.choice(movieData)

# %%
movieTransactions=[]
userTransactions=[]
for i in range(0,1000):
    firtsMovie = (random.choice(movieData))
    userTransactions.append([])
    movieTransactions.append([])
    movieTransactions[i].append(getNextMovie(firtsMovie))
    for j in range(0,30):
      movieTransactions[i].append(getNextMovie(movieTransactions[i][j]))
      userTransactions[i].append(movieTransactions[i][j][11].replace(u'\xa0', u''))

# %%
movieTransactions[0][0]
# Out:
# ['Color',
#  'Steve Oedekerk',
#  '98.0',
#  '90.0',
#  '176.0',
#  '523.0',
#  'Wanda Sykes',
#  '677.0',
#  '72601713.0',
#  'Animation|Comedy|Family',
#  'Rob Paulsen',
#  'Barnyard\xa0',
#  '21396',
#  '2055',
#  'Maurice LaMarche',
#  '1.0',
#  'cow|farmer|howl|howling at the moon|vegetarian',
#  'http://www.imdb.com/title/tt0414853/?ref_=fn_tt_tt_1',
#  '155.0',
#  'English',
#  'Germany',
#  'PG',
#  '51000000.0',
#  '2006.0',
#  '560.0',
#  '5.6',
#  '1.85',
#  '605']

# %%
userTransactions[:3]
# Out:
# [['Barnyard',
#   'Batman Forever',
#   'Mars Attacks!',
#   'The Dictator',
#   'Pocahontas',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   'The Twilight Saga: New Moon',
#   'Jingle All the Way',
#   "Dante's Peak",
#   'The Thin Red Line',
#   'Stuart Little 2',
#   '22 Jump Street',
#   'Perfume: The Story of a Murderer',
#   'Munich',
#   'Mighty Joe Young',
#   'Striptease',
#   'Eyes Wide Shut',
#   'Mulan',
#   'Flushed Away',
#   'Transcendence',
#   'How to Lose a Guy in 10 Days',
#   'Spider-Man 2',
#   'The Last Samurai',
#   'Mighty Joe Young',
#   'Titanic',
#   'Cars 2',
#   'Elizabethtown',
#   'Wall Street: Money Never Sleeps',
#   'Captain Phillips',
#   'Atlantis: The Lost Empire'],
#  ['Garfield 2',
#   'Changeling',
#   'The Hobbit: The Desolation of Smaug',
#   'Brave',
#   'The 6th Day',
#   'Garfield',
#   'Pixels',
#   'Independence Day: Resurgence',
#   'Priest',
#   'The Equalizer',
#   'Domestic Disturbance',
#   'Jupiter Ascending',
#   'Gone Girl',
#   "The Emperor's New Groove",
#   'The Avengers',
#   "Winter's Tale",
#   'Titanic',
#   'Cinderella Man',
#   'Snow White and the Huntsman',
#   'Law Abiding Citizen',
#   'American Gangster',
#   'Mission: Impossible - Ghost Protocol',
#   'Barnyard',
#   'Megamind',
#   'Rush Hour 3',
#   'Changeling',
#   'How Do You Know',
#   'The Little Prince',
#   'Mission: Impossible II',
#   'Yogi Bear'],
#  ['Pan',
#   '2 Fast 2 Furious',
#   'Jack Reacher',
#   'Crimson Tide',
#   'Eraser',
#   'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'Hotel Transylvania',
#   'Life of Pi',
#   'Monster House',
#   'Leatherheads',
#   'Kill Bill: Vol. 1',
#   'Zathura: A Space Adventure',
#   'Star Trek Beyond',
#   'The Last Airbender',
#   'Flightplan',
#   'Valkyrie',
#   'From Paris with Love',
#   'Total Recall',
#   'Terminator Salvation',
#   'Doom',
#   'Meet Joe Black',
#   'The Longest Yard',
#   'Alice Through the Looking Glass',
#   'London Has Fallen',
#   'Nine',
#   'Up Close & Personal',
#   'Ice Age: Dawn of the Dinosaurs',
#   'The Incredibles',
#   'The Equalizer',
#   'Finding Nemo']]

# %% [markdown]
# ## Training the Eclat model

# %%
from apyori import apriori
rules=apriori(userTransactions,min_support=0.003,min_confidence=0.2,min_lift=3,min_length=3,max_length=3)

# %% [markdown]
# List hasil data training:

# %%
results=list(rules)
#results
# Out:
# [RelationRecord(items=frozenset({'2012', 'Children of Men'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'2012'}), items_add=frozenset({'Children of Men'}), confidence=0.2272727272727273, lift=5.980861244019139)]),
#  RelationRecord(items=frozenset({'22 Jump Street', 'Fight Club'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'22 Jump Street'}), confidence=0.2, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'Jurassic World', '300'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'300'}), items_add=frozenset({'Jurassic World'}), confidence=0.20833333333333334, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'300', 'The Bourne Identity'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'300'}), items_add=frozenset({'The Bourne Identity'}), confidence=0.20833333333333334, lift=7.440476190476191)]),
#  RelationRecord(items=frozenset({'300', 'U-571'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'300'}), items_add=frozenset({'U-571'}), confidence=0.20833333333333334, lift=5.787037037037038)]),
#  RelationRecord(items=frozenset({'From Paris with Love', '3000 Miles to Graceland'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3000 Miles to Graceland'}), items_add=frozenset({'From Paris with Love'}), confidence=0.24, lift=7.058823529411764)]),
#  RelationRecord(items=frozenset({'True Lies', '300: Rise of an Empire'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'300: Rise of an Empire'}), items_add=frozenset({'True Lies'}), confidence=0.2, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'Tango & Cash', '47 Ronin'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tango & Cash'}), items_add=frozenset({'47 Ronin'}), confidence=0.2105263157894737, lift=6.191950464396285)]),
#  RelationRecord(items=frozenset({'A Christmas Carol', 'Spider-Man 3'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A Christmas Carol'}), items_add=frozenset({'Spider-Man 3'}), confidence=0.2173913043478261, lift=4.725897920604916)]),
#  RelationRecord(items=frozenset({'A Christmas Carol', 'The Expendables'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A Christmas Carol'}), items_add=frozenset({'The Expendables'}), confidence=0.2173913043478261, lift=6.3938618925831205)]),
#  RelationRecord(items=frozenset({'A Civil Action', 'Man of Steel'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A Civil Action'}), items_add=frozenset({'Man of Steel'}), confidence=0.2272727272727273, lift=10.822510822510823), OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'A Civil Action'}), confidence=0.23809523809523808, lift=10.822510822510823)]),
#  RelationRecord(items=frozenset({'A Good Day to Die Hard', 'Red Dawn'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A Good Day to Die Hard'}), items_add=frozenset({'Red Dawn'}), confidence=0.22222222222222224, lift=7.168458781362007)]),
#  RelationRecord(items=frozenset({'A Good Day to Die Hard', 'The Nutty Professor'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A Good Day to Die Hard'}), items_add=frozenset({'The Nutty Professor'}), confidence=0.22222222222222224, lift=9.25925925925926)]),
#  RelationRecord(items=frozenset({'A Good Day to Die Hard', 'The Twilight Saga: New Moon'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'A Good Day to Die Hard'}), items_add=frozenset({'The Twilight Saga: New Moon'}), confidence=0.22222222222222224, lift=5.847953216374269)]),
#  RelationRecord(items=frozenset({'Assassins', 'A Sound of Thunder'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Assassins'}), items_add=frozenset({'A Sound of Thunder'}), confidence=0.23076923076923078, lift=7.444168734491315)]),
#  RelationRecord(items=frozenset({"Pirates of the Caribbean: At World's End", 'Absolute Power'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Pirates of the Caribbean: At World's End"}), items_add=frozenset({'Absolute Power'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({'The Green Hornet', 'Absolute Power'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Green Hornet'}), items_add=frozenset({'Absolute Power'}), confidence=0.2173913043478261, lift=5.720823798627003)]),
#  RelationRecord(items=frozenset({'Monsters, Inc.', 'After the Sunset'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'After the Sunset'}), items_add=frozenset({'Monsters, Inc.'}), confidence=0.2, lift=7.692307692307693), OrderedStatistic(items_base=frozenset({'Monsters, Inc.'}), items_add=frozenset({'After the Sunset'}), confidence=0.23076923076923078, lift=7.692307692307693)]),
#  RelationRecord(items=frozenset({'Planet of the Apes', 'After the Sunset'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'After the Sunset'}), items_add=frozenset({'Planet of the Apes'}), confidence=0.2, lift=7.407407407407408), OrderedStatistic(items_base=frozenset({'Planet of the Apes'}), items_add=frozenset({'After the Sunset'}), confidence=0.22222222222222224, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'The Village', 'Agora'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Village'}), items_add=frozenset({'Agora'}), confidence=0.2173913043478261, lift=7.246376811594204)]),
#  RelationRecord(items=frozenset({'How Do You Know', 'Alice Through the Looking Glass'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alice Through the Looking Glass'}), items_add=frozenset({'How Do You Know'}), confidence=0.22222222222222224, lift=6.5359477124183005)]),
#  RelationRecord(items=frozenset({'Need for Speed', 'Alvin and the Chipmunks'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Need for Speed'}), items_add=frozenset({'Alvin and the Chipmunks'}), confidence=0.2, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Eagle Eye', 'Alvin and the Chipmunks: The Road Chip'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alvin and the Chipmunks: The Road Chip'}), items_add=frozenset({'Eagle Eye'}), confidence=0.23529411764705882, lift=6.033182503770739)]),
#  RelationRecord(items=frozenset({'Looney Tunes: Back in Action', 'American Reunion'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'American Reunion'}), items_add=frozenset({'Looney Tunes: Back in Action'}), confidence=0.23076923076923078, lift=6.072874493927126)]),
#  RelationRecord(items=frozenset({'American Sniper', 'Priest'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Priest'}), items_add=frozenset({'American Sniper'}), confidence=0.2, lift=5.405405405405406)]),
#  RelationRecord(items=frozenset({'Under Siege 2: Dark Territory', 'Anastasia'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Under Siege 2: Dark Territory'}), items_add=frozenset({'Anastasia'}), confidence=0.20833333333333334, lift=5.208333333333333)]),
#  RelationRecord(items=frozenset({'Anger Management', "Ocean's Thirteen"}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anger Management'}), items_add=frozenset({"Ocean's Thirteen"}), confidence=0.20833333333333334, lift=6.127450980392156)]),
#  RelationRecord(items=frozenset({'Anger Management', 'The Da Vinci Code'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Anger Management'}), items_add=frozenset({'The Da Vinci Code'}), confidence=0.20833333333333334, lift=7.183908045977011)]),
#  RelationRecord(items=frozenset({'Anna and the King', 'Stealth'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stealth'}), items_add=frozenset({'Anna and the King'}), confidence=0.20689655172413793, lift=6.674082313681868)]),
#  RelationRecord(items=frozenset({'Independence Day: Resurgence', 'Annie'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Annie'}), items_add=frozenset({'Independence Day: Resurgence'}), confidence=0.23809523809523808, lift=7.002801120448178)]),
#  RelationRecord(items=frozenset({'Eat Pray Love', 'Antz'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Eat Pray Love'}), items_add=frozenset({'Antz'}), confidence=0.23333333333333334, lift=5.303030303030304)]),
#  RelationRecord(items=frozenset({'Around the World in 80 Days', 'Planet of the Apes'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Planet of the Apes'}), items_add=frozenset({'Around the World in 80 Days'}), confidence=0.22222222222222224, lift=6.349206349206349)]),
#  RelationRecord(items=frozenset({'Arthur Christmas', 'Ted 2'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Arthur Christmas'}), items_add=frozenset({'Ted 2'}), confidence=0.23809523809523808, lift=6.613756613756614)]),
#  RelationRecord(items=frozenset({'Pacific Rim', 'Austin Powers in Goldmember'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pacific Rim'}), items_add=frozenset({'Austin Powers in Goldmember'}), confidence=0.2105263157894737, lift=5.84795321637427)]),
#  RelationRecord(items=frozenset({'End of Days', 'Avatar'}), support=0.028, ordered_statistics=[OrderedStatistic(items_base=frozenset({'End of Days'}), items_add=frozenset({'Avatar'}), confidence=0.9032258064516129, lift=4.58490257082037)]),
#  RelationRecord(items=frozenset({'Avatar', 'Man of Steel'}), support=0.018, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Man of Steel'}), items_add=frozenset({'Avatar'}), confidence=0.857142857142857, lift=4.35097897026831)]),
#  RelationRecord(items=frozenset({'Avatar', 'Star Wars: Episode I - The Phantom Menace'}), support=0.032, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars: Episode I - The Phantom Menace'}), items_add=frozenset({'Avatar'}), confidence=1.0, lift=5.0761421319796955)]),
#  RelationRecord(items=frozenset({'Avatar', 'Star Wars: Episode II - Attack of the Clones'}), support=0.03, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars: Episode II - Attack of the Clones'}), items_add=frozenset({'Avatar'}), confidence=0.9677419354838709, lift=4.912395611593253)]),
#  RelationRecord(items=frozenset({'Star Wars: Episode III - Revenge of the Sith', 'Avatar'}), support=0.027, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Star Wars: Episode III - Revenge of the Sith'}), items_add=frozenset({'Avatar'}), confidence=1.0, lift=5.0761421319796955)]),
#  RelationRecord(items=frozenset({'Avatar', 'The Amazing Spider-Man 2'}), support=0.031, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Amazing Spider-Man 2'}), items_add=frozenset({'Avatar'}), confidence=0.9393939393939393, lift=4.768497154283956)]),
#  RelationRecord(items=frozenset({'The League of Extraordinary Gentlemen', 'Avatar'}), support=0.019, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The League of Extraordinary Gentlemen'}), items_add=frozenset({'Avatar'}), confidence=0.95, lift=4.82233502538071)]),
#  RelationRecord(items=frozenset({'Bad Boys II', 'Bulletproof Monk'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bad Boys II'}), items_add=frozenset({'Bulletproof Monk'}), confidence=0.22222222222222224, lift=5.698005698005699)]),
#  RelationRecord(items=frozenset({'Dr. Dolittle 2', 'Ballistic: Ecks vs. Sever'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dr. Dolittle 2'}), items_add=frozenset({'Ballistic: Ecks vs. Sever'}), confidence=0.23809523809523808, lift=7.936507936507937)]),
#  RelationRecord(items=frozenset({'Man on Fire', 'Basic Instinct 2'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Man on Fire'}), items_add=frozenset({'Basic Instinct 2'}), confidence=0.22222222222222224, lift=5.847953216374269)]),
#  RelationRecord(items=frozenset({'Tango & Cash', 'Basic Instinct 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tango & Cash'}), items_add=frozenset({'Basic Instinct 2'}), confidence=0.2105263157894737, lift=5.54016620498615)]),
#  RelationRecord(items=frozenset({'Batman Begins', 'The Fast and the Furious'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Batman Begins'}), items_add=frozenset({'The Fast and the Furious'}), confidence=0.23333333333333334, lift=3.4313725490196076)]),
#  RelationRecord(items=frozenset({'Beowulf', 'Battle Los Angeles'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Beowulf'}), items_add=frozenset({'Battle Los Angeles'}), confidence=0.20833333333333334, lift=7.440476190476191)]),
#  RelationRecord(items=frozenset({'What Women Want', 'Be Cool'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'What Women Want'}), items_add=frozenset({'Be Cool'}), confidence=0.25, lift=7.575757575757575)]),
#  RelationRecord(items=frozenset({'Bee Movie', "Charlie's Angels: Full Throttle"}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Charlie's Angels: Full Throttle"}), items_add=frozenset({'Bee Movie'}), confidence=0.20833333333333334, lift=5.630630630630631)]),
#  RelationRecord(items=frozenset({'Beowulf', 'The Fast and the Furious'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Beowulf'}), items_add=frozenset({'The Fast and the Furious'}), confidence=0.2916666666666667, lift=4.28921568627451)]),
#  RelationRecord(items=frozenset({'G.I. Jane', 'Beverly Hills Cop III'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Beverly Hills Cop III'}), items_add=frozenset({'G.I. Jane'}), confidence=0.2272727272727273, lift=7.331378299120235)]),
#  RelationRecord(items=frozenset({'Blade II', 'Transformers: Age of Extinction'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Transformers: Age of Extinction'}), items_add=frozenset({'Blade II'}), confidence=0.2173913043478261, lift=5.720823798627003)]),
#  RelationRecord(items=frozenset({'Monsters University', 'Blood Diamond'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Blood Diamond'}), items_add=frozenset({'Monsters University'}), confidence=0.22222222222222224, lift=5.698005698005699)]),
#  RelationRecord(items=frozenset({'The Twilight Saga: New Moon', 'Bruce Almighty'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bruce Almighty'}), items_add=frozenset({'The Twilight Saga: New Moon'}), confidence=0.2, lift=5.2631578947368425)]),
#  RelationRecord(items=frozenset({"Daddy's Home", 'Bulletproof Monk'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Daddy's Home"}), items_add=frozenset({'Bulletproof Monk'}), confidence=0.2, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'Carriers', 'Flight of the Phoenix'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Carriers'}), items_add=frozenset({'Flight of the Phoenix'}), confidence=0.23529411764705882, lift=7.590132827324478)]),
#  RelationRecord(items=frozenset({'Carriers', 'Jurassic Park III'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Carriers'}), items_add=frozenset({'Jurassic Park III'}), confidence=0.23529411764705882, lift=7.1301247771836005)]),
#  RelationRecord(items=frozenset({'Carriers', 'The Insider'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Carriers'}), items_add=frozenset({'The Insider'}), confidence=0.23529411764705882, lift=7.843137254901961)]),
#  RelationRecord(items=frozenset({'Casino', 'The Nutcracker in 3D'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Casino'}), items_add=frozenset({'The Nutcracker in 3D'}), confidence=0.2, lift=6.8965517241379315), OrderedStatistic(items_base=frozenset({'The Nutcracker in 3D'}), items_add=frozenset({'Casino'}), confidence=0.20689655172413793, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Priest', 'Cats & Dogs'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Priest'}), items_add=frozenset({'Cats & Dogs'}), confidence=0.2, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'Tango & Cash', 'Cats & Dogs: The Revenge of Kitty Galore'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tango & Cash'}), items_add=frozenset({'Cats & Dogs: The Revenge of Kitty Galore'}), confidence=0.2105263157894737, lift=7.518796992481203)]),
#  RelationRecord(items=frozenset({'The Legend of Tarzan', 'Central Intelligence'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Central Intelligence'}), items_add=frozenset({'The Legend of Tarzan'}), confidence=0.25, lift=5.1020408163265305)]),
#  RelationRecord(items=frozenset({'Daddy Day Care', 'Cheaper by the Dozen 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cheaper by the Dozen 2'}), items_add=frozenset({'Daddy Day Care'}), confidence=0.2105263157894737, lift=7.017543859649123)]),
#  RelationRecord(items=frozenset({'Fantastic Four', 'Cheaper by the Dozen 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cheaper by the Dozen 2'}), items_add=frozenset({'Fantastic Four'}), confidence=0.2105263157894737, lift=3.3416875522138683)]),
#  RelationRecord(items=frozenset({'Fast Five', 'Cheaper by the Dozen 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cheaper by the Dozen 2'}), items_add=frozenset({'Fast Five'}), confidence=0.2105263157894737, lift=5.84795321637427)]),
#  RelationRecord(items=frozenset({'Godzilla Resurgence', 'Cheaper by the Dozen 2'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cheaper by the Dozen 2'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.2631578947368421, lift=5.159958720330238)]),
#  RelationRecord(items=frozenset({'In the Heart of the Sea', 'Cheaper by the Dozen 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cheaper by the Dozen 2'}), items_add=frozenset({'In the Heart of the Sea'}), confidence=0.2105263157894737, lift=7.7972709551656925)]),
#  RelationRecord(items=frozenset({'Zero Dark Thirty', 'Cheaper by the Dozen 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cheaper by the Dozen 2'}), items_add=frozenset({'Zero Dark Thirty'}), confidence=0.2105263157894737, lift=8.097165991902836)]),
#  RelationRecord(items=frozenset({'Christmas with the Kranks', 'Interstellar'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Christmas with the Kranks'}), items_add=frozenset({'Interstellar'}), confidence=0.2, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'Monkeybone', 'Christmas with the Kranks'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monkeybone'}), items_add=frozenset({'Christmas with the Kranks'}), confidence=0.2, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'Christmas with the Kranks', 'Shrek the Third'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Christmas with the Kranks'}), items_add=frozenset({'Shrek the Third'}), confidence=0.2, lift=7.407407407407408), OrderedStatistic(items_base=frozenset({'Shrek the Third'}), items_add=frozenset({'Christmas with the Kranks'}), confidence=0.22222222222222224, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'Dragon Blade', 'Cloudy with a Chance of Meatballs'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs'}), items_add=frozenset({'Dragon Blade'}), confidence=0.2608695652173913, lift=6.864988558352403)]),
#  RelationRecord(items=frozenset({'Tower Heist', 'Cloudy with a Chance of Meatballs'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs'}), items_add=frozenset({'Tower Heist'}), confidence=0.2173913043478261, lift=7.012622720897617)]),
#  RelationRecord(items=frozenset({'Wall Street: Money Never Sleeps', 'Cloudy with a Chance of Meatballs'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cloudy with a Chance of Meatballs'}), items_add=frozenset({'Wall Street: Money Never Sleeps'}), confidence=0.2173913043478261, lift=6.587615283267458)]),
#  RelationRecord(items=frozenset({'Contact', 'Dragonfly'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dragonfly'}), items_add=frozenset({'Contact'}), confidence=0.20833333333333334, lift=6.944444444444445)]),
#  RelationRecord(items=frozenset({'Crimson Tide', 'Supernova'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Crimson Tide'}), items_add=frozenset({'Supernova'}), confidence=0.22222222222222224, lift=6.734006734006734)]),
#  RelationRecord(items=frozenset({'Curious George', "Fool's Gold"}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Curious George'}), items_add=frozenset({"Fool's Gold"}), confidence=0.2, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'Imagine That', 'Curious George'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Curious George'}), items_add=frozenset({'Imagine That'}), confidence=0.2, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'Godzilla Resurgence', "Daddy's Home"}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Daddy's Home"}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.2, lift=3.9215686274509807)]),
#  RelationRecord(items=frozenset({'The Manchurian Candidate', "Daddy's Home"}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Daddy's Home"}), items_add=frozenset({'The Manchurian Candidate'}), confidence=0.2, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Days of Thunder', 'Live Free or Die Hard'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Live Free or Die Hard'}), items_add=frozenset({'Days of Thunder'}), confidence=0.25, lift=7.352941176470588)]),
#  RelationRecord(items=frozenset({'The Wolverine', 'Death Race'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Death Race'}), items_add=frozenset({'The Wolverine'}), confidence=0.2173913043478261, lift=6.793478260869565)]),
#  RelationRecord(items=frozenset({'Tomorrow Never Dies', 'Death Race'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Death Race'}), items_add=frozenset({'Tomorrow Never Dies'}), confidence=0.2173913043478261, lift=5.720823798627003)]),
#  RelationRecord(items=frozenset({'The Beach', 'Deck the Halls'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Beach'}), items_add=frozenset({'Deck the Halls'}), confidence=0.2, lift=4.081632653061225)]),
#  RelationRecord(items=frozenset({'Penguins of Madagascar', 'Deep Blue Sea'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deep Blue Sea'}), items_add=frozenset({'Penguins of Madagascar'}), confidence=0.20833333333333334, lift=4.844961240310078)]),
#  RelationRecord(items=frozenset({'Deep Impact', 'Star Wars: Episode III - Revenge of the Sith'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Deep Impact'}), items_add=frozenset({'Star Wars: Episode III - Revenge of the Sith'}), confidence=0.20689655172413793, lift=7.662835249042145), OrderedStatistic(items_base=frozenset({'Star Wars: Episode III - Revenge of the Sith'}), items_add=frozenset({'Deep Impact'}), confidence=0.22222222222222224, lift=7.662835249042145)]),
#  RelationRecord(items=frozenset({'Did You Hear About the Morgans?', 'Fantastic Four'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Did You Hear About the Morgans?'}), items_add=frozenset({'Fantastic Four'}), confidence=0.20588235294117646, lift=3.2679738562091503)]),
#  RelationRecord(items=frozenset({'Jack Reacher', 'Die Hard 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack Reacher'}), items_add=frozenset({'Die Hard 2'}), confidence=0.23529411764705882, lift=6.359300476947536)]),
#  RelationRecord(items=frozenset({'Die Hard with a Vengeance', 'Inside Out'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Die Hard with a Vengeance'}), items_add=frozenset({'Inside Out'}), confidence=0.20833333333333334, lift=5.630630630630631)]),
#  RelationRecord(items=frozenset({'Money Train', 'Doom'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Money Train'}), items_add=frozenset({'Doom'}), confidence=0.22222222222222224, lift=6.349206349206349)]),
#  RelationRecord(items=frozenset({'Rise of the Guardians', 'Doom'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Rise of the Guardians'}), items_add=frozenset({'Doom'}), confidence=0.20833333333333334, lift=5.952380952380952)]),
#  RelationRecord(items=frozenset({'Dr. Dolittle 2', 'U-571'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dr. Dolittle 2'}), items_add=frozenset({'U-571'}), confidence=0.23809523809523808, lift=6.613756613756614)]),
#  RelationRecord(items=frozenset({'Pirates of the Caribbean: The Curse of the Black Pearl', 'Dragon Blade'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pirates of the Caribbean: The Curse of the Black Pearl'}), items_add=frozenset({'Dragon Blade'}), confidence=0.22222222222222224, lift=5.847953216374269)]),
#  RelationRecord(items=frozenset({'The Mask of Zorro', 'Dreamcatcher'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Mask of Zorro'}), items_add=frozenset({'Dreamcatcher'}), confidence=0.2272727272727273, lift=7.836990595611286)]),
#  RelationRecord(items=frozenset({'Dredd', 'Minions'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Minions'}), items_add=frozenset({'Dredd'}), confidence=0.20833333333333334, lift=5.787037037037038)]),
#  RelationRecord(items=frozenset({'Dredd', 'Stuck on You'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stuck on You'}), items_add=frozenset({'Dredd'}), confidence=0.2105263157894737, lift=5.84795321637427)]),
#  RelationRecord(items=frozenset({'Edge of Darkness', 'What Lies Beneath'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'What Lies Beneath'}), items_add=frozenset({'Edge of Darkness'}), confidence=0.2, lift=7.142857142857143)]),
#  RelationRecord(items=frozenset({'Fantastic Four', 'Elektra'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Elektra'}), items_add=frozenset({'Fantastic Four'}), confidence=0.2, lift=3.174603174603175)]),
#  RelationRecord(items=frozenset({'Man on Fire', 'Elektra'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Elektra'}), items_add=frozenset({'Man on Fire'}), confidence=0.2, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'The Hobbit: The Battle of the Five Armies', 'Elektra'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Elektra'}), items_add=frozenset({'The Hobbit: The Battle of the Five Armies'}), confidence=0.25, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'Immortals', 'Elizabeth: The Golden Age'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Immortals'}), items_add=frozenset({'Elizabeth: The Golden Age'}), confidence=0.2173913043478261, lift=5.875440658049355)]),
#  RelationRecord(items=frozenset({'Terminator 3: Rise of the Machines', 'Elysium'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Elysium'}), items_add=frozenset({'Terminator 3: Rise of the Machines'}), confidence=0.2, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'The Expendables 2', 'Epic'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Expendables 2'}), items_add=frozenset({'Epic'}), confidence=0.2, lift=8.333333333333334)]),
#  RelationRecord(items=frozenset({'Eraser', 'Hop'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hop'}), items_add=frozenset({'Eraser'}), confidence=0.2105263157894737, lift=9.569377990430624)]),
#  RelationRecord(items=frozenset({'Evan Almighty', 'Shrek the Third'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Shrek the Third'}), items_add=frozenset({'Evan Almighty'}), confidence=0.22222222222222224, lift=5.291005291005291)]),
#  RelationRecord(items=frozenset({'The Lone Ranger', 'Evan Almighty'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Lone Ranger'}), items_add=frozenset({'Evan Almighty'}), confidence=0.2, lift=4.761904761904762)]),
#  RelationRecord(items=frozenset({'Evan Almighty', 'Æon Flux'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Æon Flux'}), items_add=frozenset({'Evan Almighty'}), confidence=0.20833333333333334, lift=4.9603174603174605)]),
#  RelationRecord(items=frozenset({'Event Horizon', 'Stealth'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Event Horizon'}), items_add=frozenset({'Stealth'}), confidence=0.20833333333333334, lift=7.183908045977011)]),
#  RelationRecord(items=frozenset({'Fantastic Four', 'Home on the Range'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Home on the Range'}), items_add=frozenset({'Fantastic Four'}), confidence=0.20689655172413793, lift=3.284072249589491)]),
#  RelationRecord(items=frozenset({'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'Fantastic Four'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe'}), items_add=frozenset({'Fantastic Four'}), confidence=0.22222222222222224, lift=3.5273368606701943)]),
#  RelationRecord(items=frozenset({'The Hateful Eight', 'Fantastic Four'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Hateful Eight'}), items_add=frozenset({'Fantastic Four'}), confidence=0.2173913043478261, lift=3.4506556245686686)]),
#  RelationRecord(items=frozenset({'Insurgent', 'Fight Club'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Insurgent'}), confidence=0.2, lift=4.761904761904762)]),
#  RelationRecord(items=frozenset({'Fight Club', 'Mamma Mia!'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'Mamma Mia!'}), confidence=0.26666666666666666, lift=8.88888888888889)]),
#  RelationRecord(items=frozenset({'The Dilemma', 'Fight Club'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fight Club'}), items_add=frozenset({'The Dilemma'}), confidence=0.2, lift=5.128205128205129)]),
#  RelationRecord(items=frozenset({'V for Vendetta', 'Flags of Our Fathers'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'V for Vendetta'}), items_add=frozenset({'Flags of Our Fathers'}), confidence=0.25, lift=7.142857142857142)]),
#  RelationRecord(items=frozenset({'Flyboys', 'Gremlins 2: The New Batch'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Flyboys'}), items_add=frozenset({'Gremlins 2: The New Batch'}), confidence=0.2608695652173913, lift=7.672634271099743)]),
#  RelationRecord(items=frozenset({'Focus', 'Tango & Cash'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tango & Cash'}), items_add=frozenset({'Focus'}), confidence=0.2105263157894737, lift=7.017543859649123)]),
#  RelationRecord(items=frozenset({'K-19: The Widowmaker', 'For Love of the Game'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'K-19: The Widowmaker'}), items_add=frozenset({'For Love of the Game'}), confidence=0.21428571428571427, lift=5.7915057915057915)]),
#  RelationRecord(items=frozenset({'Pacific Rim', 'For Love of the Game'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pacific Rim'}), items_add=frozenset({'For Love of the Game'}), confidence=0.2631578947368421, lift=7.112375533428165)]),
#  RelationRecord(items=frozenset({'Mirror Mirror', 'Four Christmases'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Four Christmases'}), items_add=frozenset({'Mirror Mirror'}), confidence=0.20689655172413793, lift=5.44464609800363)]),
#  RelationRecord(items=frozenset({'Free Birds', 'The League of Extraordinary Gentlemen'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The League of Extraordinary Gentlemen'}), items_add=frozenset({'Free Birds'}), confidence=0.2, lift=7.692307692307693)]),
#  RelationRecord(items=frozenset({'From Paris with Love', 'The Judge'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Judge'}), items_add=frozenset({'From Paris with Love'}), confidence=0.23529411764705882, lift=6.920415224913494)]),
#  RelationRecord(items=frozenset({'G.I. Jane', 'Æon Flux'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Æon Flux'}), items_add=frozenset({'G.I. Jane'}), confidence=0.20833333333333334, lift=6.720430107526882)]),
#  RelationRecord(items=frozenset({'G.I. Joe: The Rise of Cobra', 'Monkeybone'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monkeybone'}), items_add=frozenset({'G.I. Joe: The Rise of Cobra'}), confidence=0.2, lift=6.25)]),
#  RelationRecord(items=frozenset({'George of the Jungle', 'Jack Reacher'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack Reacher'}), items_add=frozenset({'George of the Jungle'}), confidence=0.23529411764705882, lift=8.403361344537815)]),
#  RelationRecord(items=frozenset({'Godzilla Resurgence', 'The Ridiculous 6'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Ridiculous 6'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.2, lift=3.9215686274509807)]),
#  RelationRecord(items=frozenset({'Transformers', 'Godzilla Resurgence'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Transformers'}), items_add=frozenset({'Godzilla Resurgence'}), confidence=0.23809523809523808, lift=4.6685340802987865)]),
#  RelationRecord(items=frozenset({'Gone Girl', 'Jupiter Ascending'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Gone Girl'}), items_add=frozenset({'Jupiter Ascending'}), confidence=0.2173913043478261, lift=6.793478260869565)]),
#  RelationRecord(items=frozenset({'Grindhouse', 'The A-Team'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The A-Team'}), items_add=frozenset({'Grindhouse'}), confidence=0.21428571428571427, lift=5.639097744360902)]),
#  RelationRecord(items=frozenset({'Hairspray', 'The Brothers Grimm'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hairspray'}), items_add=frozenset({'The Brothers Grimm'}), confidence=0.2105263157894737, lift=6.379585326953748)]),
#  RelationRecord(items=frozenset({'Harry Potter and the Chamber of Secrets', 'The Fast and the Furious'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Harry Potter and the Chamber of Secrets'}), items_add=frozenset({'The Fast and the Furious'}), confidence=0.23333333333333334, lift=3.4313725490196076)]),
#  RelationRecord(items=frozenset({'Harry Potter and the Half-Blood Prince', 'Kung Fu Panda 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Harry Potter and the Half-Blood Prince'}), items_add=frozenset({'Kung Fu Panda 2'}), confidence=0.2, lift=6.0606060606060606)]),
#  RelationRecord(items=frozenset({'V for Vendetta', "Hart's War"}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'V for Vendetta'}), items_add=frozenset({"Hart's War"}), confidence=0.2, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Hellboy', 'Rules of Engagement'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hellboy'}), items_add=frozenset({'Rules of Engagement'}), confidence=0.2272727272727273, lift=7.836990595611286)]),
#  RelationRecord(items=frozenset({'Hercules', 'Sleepy Hollow'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Sleepy Hollow'}), items_add=frozenset({'Hercules'}), confidence=0.22222222222222224, lift=5.050505050505051)]),
#  RelationRecord(items=frozenset({'Nine', 'Hitch'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hitch'}), items_add=frozenset({'Nine'}), confidence=0.20689655172413793, lift=8.275862068965516), OrderedStatistic(items_base=frozenset({'Nine'}), items_add=frozenset({'Hitch'}), confidence=0.24, lift=8.275862068965516)]),
#  RelationRecord(items=frozenset({'Troy', 'Hitch'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hitch'}), items_add=frozenset({'Troy'}), confidence=0.20689655172413793, lift=6.674082313681868)]),
#  RelationRecord(items=frozenset({'Inglourious Basterds', 'Hotel Transylvania 2'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hotel Transylvania 2'}), items_add=frozenset({'Inglourious Basterds'}), confidence=0.20588235294117646, lift=5.5643879173290935)]),
#  RelationRecord(items=frozenset({'Hudson Hawk', 'Year One'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Year One'}), items_add=frozenset({'Hudson Hawk'}), confidence=0.20833333333333334, lift=7.440476190476191)]),
#  RelationRecord(items=frozenset({'I Am Legend', 'Ransom'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'I Am Legend'}), items_add=frozenset({'Ransom'}), confidence=0.20689655172413793, lift=8.275862068965516), OrderedStatistic(items_base=frozenset({'Ransom'}), items_add=frozenset({'I Am Legend'}), confidence=0.24, lift=8.275862068965516)]),
#  RelationRecord(items=frozenset({'I Spy', 'The Siege'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Siege'}), items_add=frozenset({'I Spy'}), confidence=0.2, lift=7.407407407407408)]),
#  RelationRecord(items=frozenset({'Inglourious Basterds', 'The Matrix Reloaded'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Matrix Reloaded'}), items_add=frozenset({'Inglourious Basterds'}), confidence=0.20689655172413793, lift=5.591798695246971)]),
#  RelationRecord(items=frozenset({'V for Vendetta', 'Into the Woods'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'V for Vendetta'}), items_add=frozenset({'Into the Woods'}), confidence=0.2, lift=6.25)]),
#  RelationRecord(items=frozenset({'Jack Reacher', 'Public Enemies'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jack Reacher'}), items_add=frozenset({'Public Enemies'}), confidence=0.23529411764705882, lift=6.535947712418301)]),
#  RelationRecord(items=frozenset({'Jack Ryan: Shadow Recruit', "Pirates of the Caribbean: At World's End"}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Pirates of the Caribbean: At World's End"}), items_add=frozenset({'Jack Ryan: Shadow Recruit'}), confidence=0.2, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({'Jack and Jill', 'The Siege'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Siege'}), items_add=frozenset({'Jack and Jill'}), confidence=0.2, lift=6.666666666666667)]),
#  RelationRecord(items=frozenset({'Just Go with It', 'Kung Fu Panda 2'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Just Go with It'}), items_add=frozenset({'Kung Fu Panda 2'}), confidence=0.25, lift=7.575757575757575)]),
#  RelationRecord(items=frozenset({'The Avengers', 'King Kong'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'King Kong'}), items_add=frozenset({'The Avengers'}), confidence=0.2105263157894737, lift=3.189792663476874)]),
#  RelationRecord(items=frozenset({'Last Action Hero', 'The Avengers'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Last Action Hero'}), items_add=frozenset({'The Avengers'}), confidence=0.20689655172413793, lift=3.134796238244514)]),
#  RelationRecord(items=frozenset({"Mr. Popper's Penguins", 'Law Abiding Citizen'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Law Abiding Citizen'}), items_add=frozenset({"Mr. Popper's Penguins"}), confidence=0.23333333333333334, lift=8.045977011494253), OrderedStatistic(items_base=frozenset({"Mr. Popper's Penguins"}), items_add=frozenset({'Law Abiding Citizen'}), confidence=0.24137931034482757, lift=8.045977011494253)]),
#  RelationRecord(items=frozenset({'World Trade Center', 'Leatherheads'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Leatherheads'}), items_add=frozenset({'World Trade Center'}), confidence=0.23809523809523808, lift=6.435006435006435)]),
#  RelationRecord(items=frozenset({"The Sorcerer's Apprentice", 'Lilo & Stitch'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({"The Sorcerer's Apprentice"}), items_add=frozenset({'Lilo & Stitch'}), confidence=0.2, lift=5.0)]),
#  RelationRecord(items=frozenset({'Total Recall', 'Live Free or Die Hard'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Live Free or Die Hard'}), items_add=frozenset({'Total Recall'}), confidence=0.2, lift=4.166666666666667)]),
#  RelationRecord(items=frozenset({'Man on Fire', 'The Day the Earth Stood Still'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Day the Earth Stood Still'}), items_add=frozenset({'Man on Fire'}), confidence=0.20833333333333334, lift=7.71604938271605)]),
#  RelationRecord(items=frozenset({'Year One', 'Marmaduke'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Year One'}), items_add=frozenset({'Marmaduke'}), confidence=0.20833333333333334, lift=5.787037037037038)]),
#  RelationRecord(items=frozenset({'Master and Commander: The Far Side of the World', 'The Tourist'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Tourist'}), items_add=frozenset({'Master and Commander: The Far Side of the World'}), confidence=0.2, lift=6.451612903225807)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Megamind'}), support=0.007, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Megamind'}), items_add=frozenset({'The Avengers'}), confidence=0.22580645161290322, lift=3.4213098729227758)]),
#  RelationRecord(items=frozenset({'Outbreak', 'Men in Black'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Men in Black'}), items_add=frozenset({'Outbreak'}), confidence=0.2, lift=6.8965517241379315)]),
#  RelationRecord(items=frozenset({'Trouble with the Curve', 'Men in Black'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Men in Black'}), items_add=frozenset({'Trouble with the Curve'}), confidence=0.2, lift=6.0606060606060606)]),
#  RelationRecord(items=frozenset({'Mission to Mars', 'Thirteen Days'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Mission to Mars'}), items_add=frozenset({'Thirteen Days'}), confidence=0.20689655172413793, lift=6.4655172413793105)]),
#  RelationRecord(items=frozenset({'Ronin', 'Mission: Impossible II'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ronin'}), items_add=frozenset({'Mission: Impossible II'}), confidence=0.2173913043478261, lift=5.302226935312832)]),
#  RelationRecord(items=frozenset({'Moneyball', 'The Avengers'}), support=0.008, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Moneyball'}), items_add=frozenset({'The Avengers'}), confidence=0.23529411764705882, lift=3.5650623885918002)]),
#  RelationRecord(items=frozenset({"The Devil's Own", 'Monster House'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({"The Devil's Own"}), items_add=frozenset({'Monster House'}), confidence=0.2, lift=5.555555555555556)]),
#  RelationRecord(items=frozenset({"The Huntsman: Winter's War", 'My Favorite Martian'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({"The Huntsman: Winter's War"}), items_add=frozenset({'My Favorite Martian'}), confidence=0.2173913043478261, lift=7.496251874062969)]),
#  RelationRecord(items=frozenset({"Ocean's Twelve", 'The Flintstones in Viva Rock Vegas'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Ocean's Twelve"}), items_add=frozenset({'The Flintstones in Viva Rock Vegas'}), confidence=0.25, lift=6.097560975609756)]),
#  RelationRecord(items=frozenset({'Over the Hedge', 'The Twilight Saga: Breaking Dawn - Part 2'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Over the Hedge'}), items_add=frozenset({'The Twilight Saga: Breaking Dawn - Part 2'}), confidence=0.20833333333333334, lift=3.787878787878788)]),
#  RelationRecord(items=frozenset({'Pan', 'Stuck on You'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stuck on You'}), items_add=frozenset({'Pan'}), confidence=0.2105263157894737, lift=4.12796697626419)]),
#  RelationRecord(items=frozenset({'Pan', 'The Tourist'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Tourist'}), items_add=frozenset({'Pan'}), confidence=0.2, lift=3.9215686274509807)]),
#  RelationRecord(items=frozenset({'Paycheck', 'Practical Magic'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Paycheck'}), items_add=frozenset({'Practical Magic'}), confidence=0.20833333333333334, lift=6.510416666666667)]),
#  RelationRecord(items=frozenset({'Raising Helen', 'Pirates of the Caribbean: The Curse of the Black Pearl'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Raising Helen'}), items_add=frozenset({'Pirates of the Caribbean: The Curse of the Black Pearl'}), confidence=0.23529411764705882, lift=8.714596949891067)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Point Break'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Point Break'}), items_add=frozenset({'The Avengers'}), confidence=0.20689655172413793, lift=3.134796238244514)]),
#  RelationRecord(items=frozenset({'Practical Magic', 'Seabiscuit'}), support=0.006, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Seabiscuit'}), items_add=frozenset({'Practical Magic'}), confidence=0.20689655172413793, lift=6.4655172413793105)]),
#  RelationRecord(items=frozenset({'Stuck on You', 'R.I.P.D.'}), support=0.004, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Stuck on You'}), items_add=frozenset({'R.I.P.D.'}), confidence=0.2105263157894737, lift=6.191950464396285)]),
#  RelationRecord(items=frozenset({'RED', 'The Fast and the Furious'}), support=0.005, ordered_statistics=[OrderedStatistic(items_base=frozenset({'RED'}), items_add=frozenset({'The Fast and the Furious'}), confidence=0.20833333333333334, lift=3.063725490196078)]),
# ...
#  RelationRecord(items=frozenset({'The Hunchback of Notre Dame', 'How to Lose a Guy in 10 Days', "Something's Gotta Give"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'How to Lose a Guy in 10 Days', "Something's Gotta Give"}), items_add=frozenset({'The Hunchback of Notre Dame'}), confidence=1.0, lift=31.25), OrderedStatistic(items_base=frozenset({'The Hunchback of Notre Dame', 'How to Lose a Guy in 10 Days'}), items_add=frozenset({"Something's Gotta Give"}), confidence=0.75, lift=24.193548387096776), OrderedStatistic(items_base=frozenset({'The Hunchback of Notre Dame', "Something's Gotta Give"}), items_add=frozenset({'How to Lose a Guy in 10 Days'}), confidence=0.75, lift=20.833333333333336)]),
#  RelationRecord(items=frozenset({'Out of Time', 'Monster House', 'Hugo'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Monster House', 'Hugo'}), items_add=frozenset({'Out of Time'}), confidence=1.0, lift=38.46153846153846), OrderedStatistic(items_base=frozenset({'Out of Time', 'Hugo'}), items_add=frozenset({'Monster House'}), confidence=0.75, lift=20.833333333333336), OrderedStatistic(items_base=frozenset({'Out of Time', 'Monster House'}), items_add=frozenset({'Hugo'}), confidence=1.0, lift=29.41176470588235)]),
#  RelationRecord(items=frozenset({'Spectre', 'I, Robot', 'Spirit: Stallion of the Cimarron'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Spectre', 'I, Robot'}), items_add=frozenset({'Spirit: Stallion of the Cimarron'}), confidence=0.5, lift=16.129032258064516), OrderedStatistic(items_base=frozenset({'I, Robot', 'Spirit: Stallion of the Cimarron'}), items_add=frozenset({'Spectre'}), confidence=0.75, lift=17.857142857142858), OrderedStatistic(items_base=frozenset({'Spectre', 'Spirit: Stallion of the Cimarron'}), items_add=frozenset({'I, Robot'}), confidence=0.6, lift=19.35483870967742)]),
#  RelationRecord(items=frozenset({'Invictus', 'Rise of the Planet of the Apes', 'Ice Age: The Meltdown'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Invictus', 'Ice Age: The Meltdown'}), items_add=frozenset({'Rise of the Planet of the Apes'}), confidence=1.0, lift=37.03703703703704), OrderedStatistic(items_base=frozenset({'Rise of the Planet of the Apes', 'Ice Age: The Meltdown'}), items_add=frozenset({'Invictus'}), confidence=1.0, lift=35.714285714285715), OrderedStatistic(items_base=frozenset({'Invictus', 'Rise of the Planet of the Apes'}), items_add=frozenset({'Ice Age: The Meltdown'}), confidence=1.0, lift=41.666666666666664)]),
#  RelationRecord(items=frozenset({'In the Heart of the Sea', 'Mirror Mirror', 'Jerry Maguire'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'In the Heart of the Sea', 'Jerry Maguire'}), items_add=frozenset({'Mirror Mirror'}), confidence=0.6, lift=15.789473684210526), OrderedStatistic(items_base=frozenset({'In the Heart of the Sea', 'Mirror Mirror'}), items_add=frozenset({'Jerry Maguire'}), confidence=0.75, lift=19.23076923076923), OrderedStatistic(items_base=frozenset({'Mirror Mirror', 'Jerry Maguire'}), items_add=frozenset({'In the Heart of the Sea'}), confidence=1.0, lift=37.03703703703704)]),
#  RelationRecord(items=frozenset({'John Carter', 'The Man from U.N.C.L.E.', 'Inside Out'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'John Carter', 'Inside Out'}), items_add=frozenset({'The Man from U.N.C.L.E.'}), confidence=1.0, lift=33.333333333333336), OrderedStatistic(items_base=frozenset({'The Man from U.N.C.L.E.', 'Inside Out'}), items_add=frozenset({'John Carter'}), confidence=1.0, lift=45.45454545454546), OrderedStatistic(items_base=frozenset({'John Carter', 'The Man from U.N.C.L.E.'}), items_add=frozenset({'Inside Out'}), confidence=1.0, lift=27.027027027027028)]),
#  RelationRecord(items=frozenset({'Ratatouille', 'The Pirates! Band of Misfits', 'Inside Out'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Ratatouille', 'Inside Out'}), items_add=frozenset({'The Pirates! Band of Misfits'}), confidence=0.75, lift=20.27027027027027), OrderedStatistic(items_base=frozenset({'The Pirates! Band of Misfits', 'Inside Out'}), items_add=frozenset({'Ratatouille'}), confidence=0.75, lift=25.0), OrderedStatistic(items_base=frozenset({'Ratatouille', 'The Pirates! Band of Misfits'}), items_add=frozenset({'Inside Out'}), confidence=1.0, lift=27.027027027027028)]),
#  RelationRecord(items=frozenset({'Speed Racer', 'Stealth', 'Inside Out'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Speed Racer', 'Inside Out'}), items_add=frozenset({'Stealth'}), confidence=0.6, lift=20.68965517241379), OrderedStatistic(items_base=frozenset({'Stealth', 'Inside Out'}), items_add=frozenset({'Speed Racer'}), confidence=1.0, lift=28.57142857142857), OrderedStatistic(items_base=frozenset({'Stealth', 'Speed Racer'}), items_add=frozenset({'Inside Out'}), confidence=1.0, lift=27.027027027027028)]),
#  RelationRecord(items=frozenset({'The Flowers of War', 'Inspector Gadget', 'Wreck-It Ralph'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Flowers of War', 'Inspector Gadget'}), items_add=frozenset({'Wreck-It Ralph'}), confidence=0.6, lift=27.272727272727273), OrderedStatistic(items_base=frozenset({'Inspector Gadget', 'Wreck-It Ralph'}), items_add=frozenset({'The Flowers of War'}), confidence=0.75, lift=24.193548387096776), OrderedStatistic(items_base=frozenset({'The Flowers of War', 'Wreck-It Ralph'}), items_add=frozenset({'Inspector Gadget'}), confidence=1.0, lift=35.714285714285715)]),
#  RelationRecord(items=frozenset({'Munich', 'The Hunger Games', 'Interstellar'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Munich', 'Interstellar'}), items_add=frozenset({'The Hunger Games'}), confidence=0.6, lift=18.18181818181818), OrderedStatistic(items_base=frozenset({'The Hunger Games', 'Interstellar'}), items_add=frozenset({'Munich'}), confidence=1.0, lift=27.77777777777778), OrderedStatistic(items_base=frozenset({'Munich', 'The Hunger Games'}), items_add=frozenset({'Interstellar'}), confidence=0.75, lift=20.833333333333336)]),
#  RelationRecord(items=frozenset({'The Twilight Saga: New Moon', 'Interstellar', 'Pixels'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Interstellar', 'Pixels'}), items_add=frozenset({'The Twilight Saga: New Moon'}), confidence=0.75, lift=19.736842105263158), OrderedStatistic(items_base=frozenset({'The Twilight Saga: New Moon', 'Interstellar'}), items_add=frozenset({'Pixels'}), confidence=1.0, lift=26.315789473684212), OrderedStatistic(items_base=frozenset({'The Twilight Saga: New Moon', 'Pixels'}), items_add=frozenset({'Interstellar'}), confidence=0.5, lift=13.88888888888889)]),
#  RelationRecord(items=frozenset({'Shrek Forever After', 'The Scorch Trials', 'Interstellar'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Shrek Forever After', 'Interstellar'}), items_add=frozenset({'The Scorch Trials'}), confidence=0.75, lift=17.44186046511628), OrderedStatistic(items_base=frozenset({'The Scorch Trials', 'Interstellar'}), items_add=frozenset({'Shrek Forever After'}), confidence=0.6, lift=15.0), OrderedStatistic(items_base=frozenset({'Shrek Forever After', 'The Scorch Trials'}), items_add=frozenset({'Interstellar'}), confidence=0.75, lift=20.833333333333336)]),
#  RelationRecord(items=frozenset({'Into the Storm', 'The Break-Up', 'The Book of Eli'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Into the Storm', 'The Book of Eli'}), items_add=frozenset({'The Break-Up'}), confidence=1.0, lift=32.25806451612903), OrderedStatistic(items_base=frozenset({'Into the Storm', 'The Break-Up'}), items_add=frozenset({'The Book of Eli'}), confidence=1.0, lift=38.46153846153846), OrderedStatistic(items_base=frozenset({'The Break-Up', 'The Book of Eli'}), items_add=frozenset({'Into the Storm'}), confidence=0.5, lift=18.51851851851852)]),
#  RelationRecord(items=frozenset({'Poseidon', 'The Avengers', 'Intolerable Cruelty'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Poseidon', 'Intolerable Cruelty'}), items_add=frozenset({'The Avengers'}), confidence=1.0, lift=15.15151515151515), OrderedStatistic(items_base=frozenset({'The Avengers', 'Intolerable Cruelty'}), items_add=frozenset({'Poseidon'}), confidence=0.6, lift=22.22222222222222), OrderedStatistic(items_base=frozenset({'Poseidon', 'The Avengers'}), items_add=frozenset({'Intolerable Cruelty'}), confidence=0.6, lift=23.076923076923077)]),
#  RelationRecord(items=frozenset({'Iron Man 2', 'Monsters vs. Aliens', 'The Fast and the Furious'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Iron Man 2', 'Monsters vs. Aliens'}), items_add=frozenset({'The Fast and the Furious'}), confidence=1.0, lift=14.705882352941176), OrderedStatistic(items_base=frozenset({'Iron Man 2', 'The Fast and the Furious'}), items_add=frozenset({'Monsters vs. Aliens'}), confidence=0.5, lift=16.129032258064516), OrderedStatistic(items_base=frozenset({'Monsters vs. Aliens', 'The Fast and the Furious'}), items_add=frozenset({'Iron Man 2'}), confidence=0.6, lift=13.953488372093023)]),
#  RelationRecord(items=frozenset({'The Last Airbender', 'The Love Guru', 'Iron Man 2'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Last Airbender', 'Iron Man 2'}), items_add=frozenset({'The Love Guru'}), confidence=1.0, lift=32.25806451612903), OrderedStatistic(items_base=frozenset({'The Love Guru', 'Iron Man 2'}), items_add=frozenset({'The Last Airbender'}), confidence=0.75, lift=18.29268292682927), OrderedStatistic(items_base=frozenset({'The Last Airbender', 'The Love Guru'}), items_add=frozenset({'Iron Man 2'}), confidence=0.6, lift=13.953488372093023)]),
#  RelationRecord(items=frozenset({'Iron Man 3', 'Rollerball', 'Rio 2'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Iron Man 3', 'Rio 2'}), items_add=frozenset({'Rollerball'}), confidence=0.6, lift=15.789473684210526), OrderedStatistic(items_base=frozenset({'Iron Man 3', 'Rollerball'}), items_add=frozenset({'Rio 2'}), confidence=0.75, lift=21.428571428571427), OrderedStatistic(items_base=frozenset({'Rollerball', 'Rio 2'}), items_add=frozenset({'Iron Man 3'}), confidence=0.75, lift=24.193548387096776)]),
#  RelationRecord(items=frozenset({'Money Train', 'The Incredible Hulk', "It's Complicated"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Money Train', "It's Complicated"}), items_add=frozenset({'The Incredible Hulk'}), confidence=1.0, lift=38.46153846153846), OrderedStatistic(items_base=frozenset({'The Incredible Hulk', "It's Complicated"}), items_add=frozenset({'Money Train'}), confidence=1.0, lift=37.03703703703704), OrderedStatistic(items_base=frozenset({'Money Train', 'The Incredible Hulk'}), items_add=frozenset({"It's Complicated"}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'Noah', 'Red Tails', "It's Complicated"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Noah', "It's Complicated"}), items_add=frozenset({'Red Tails'}), confidence=0.75, lift=41.66666666666667), OrderedStatistic(items_base=frozenset({'Red Tails', "It's Complicated"}), items_add=frozenset({'Noah'}), confidence=1.0, lift=33.333333333333336), OrderedStatistic(items_base=frozenset({'Noah', 'Red Tails'}), items_add=frozenset({"It's Complicated"}), confidence=1.0, lift=28.57142857142857)]),
#  RelationRecord(items=frozenset({'Six Days Seven Nights', 'The Avengers', "It's Complicated"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Six Days Seven Nights', "It's Complicated"}), items_add=frozenset({'The Avengers'}), confidence=0.75, lift=11.363636363636363), OrderedStatistic(items_base=frozenset({'The Avengers', "It's Complicated"}), items_add=frozenset({'Six Days Seven Nights'}), confidence=0.42857142857142855, lift=15.873015873015872), OrderedStatistic(items_base=frozenset({'Six Days Seven Nights', 'The Avengers'}), items_add=frozenset({"It's Complicated"}), confidence=0.6, lift=17.142857142857142)]),
#  RelationRecord(items=frozenset({'Six Days Seven Nights', 'Year One', "It's Complicated"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Six Days Seven Nights', "It's Complicated"}), items_add=frozenset({'Year One'}), confidence=0.75, lift=31.25), OrderedStatistic(items_base=frozenset({'Year One', "It's Complicated"}), items_add=frozenset({'Six Days Seven Nights'}), confidence=1.0, lift=37.03703703703704), OrderedStatistic(items_base=frozenset({'Six Days Seven Nights', 'Year One'}), items_add=frozenset({"It's Complicated"}), confidence=0.75, lift=21.428571428571427)]),
#  RelationRecord(items=frozenset({'The Avengers', 'Year One', "It's Complicated"}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'The Avengers', "It's Complicated"}), items_add=frozenset({'Year One'}), confidence=0.42857142857142855, lift=17.857142857142854), OrderedStatistic(items_base=frozenset({'Year One', "It's Complicated"}), items_add=frozenset({'The Avengers'}), confidence=1.0, lift=15.15151515151515), OrderedStatistic(items_base=frozenset({'The Avengers', 'Year One'}), items_add=frozenset({"It's Complicated"}), confidence=0.6, lift=17.142857142857142)]),
#  RelationRecord(items=frozenset({'We Are Marshall', 'Jason Bourne', 'Lethal Weapon 4'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jason Bourne', 'Lethal Weapon 4'}), items_add=frozenset({'We Are Marshall'}), confidence=1.0, lift=31.25), OrderedStatistic(items_base=frozenset({'We Are Marshall', 'Jason Bourne'}), items_add=frozenset({'Lethal Weapon 4'}), confidence=1.0, lift=30.3030303030303), OrderedStatistic(items_base=frozenset({'We Are Marshall', 'Lethal Weapon 4'}), items_add=frozenset({'Jason Bourne'}), confidence=1.0, lift=40.0)]),
#  RelationRecord(items=frozenset({'Jerry Maguire', 'What Dreams May Come', 'Public Enemies'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jerry Maguire', 'Public Enemies'}), items_add=frozenset({'What Dreams May Come'}), confidence=1.0, lift=25.0), OrderedStatistic(items_base=frozenset({'Jerry Maguire', 'What Dreams May Come'}), items_add=frozenset({'Public Enemies'}), confidence=0.6, lift=16.666666666666668), OrderedStatistic(items_base=frozenset({'What Dreams May Come', 'Public Enemies'}), items_add=frozenset({'Jerry Maguire'}), confidence=0.75, lift=19.23076923076923)]),
#  RelationRecord(items=frozenset({'The Lovely Bones', 'Shanghai Noon', 'Joy'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Shanghai Noon', 'Joy'}), items_add=frozenset({'The Lovely Bones'}), confidence=1.0, lift=40.0), OrderedStatistic(items_base=frozenset({'The Lovely Bones', 'Joy'}), items_add=frozenset({'Shanghai Noon'}), confidence=0.75, lift=25.86206896551724), OrderedStatistic(items_base=frozenset({'The Lovely Bones', 'Shanghai Noon'}), items_add=frozenset({'Joy'}), confidence=0.75, lift=22.727272727272727)]),
#  RelationRecord(items=frozenset({'Jurassic Park III', 'U-571', 'Road to Perdition'}), support=0.003, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Jurassic Park III', 'Road to Perdition'}), items_add=frozenset({'U-571'}), confidence=1.0, lift=27.77777777777778), OrderedStatistic(items_base=frozenset({'Jurassic Park III', 'U-571'}), items_add=frozenset({'Road to Perdition'}), confidence=0.75, lift=22.727272727272727), OrderedStatistic(items_base=frozenset({'U-571', 'Road to Perdition'}), items_add=frozenset({'Jurassic Park III'}), confidence=1.0, lift=30.3030303030303)]),
#  ...]

# %% [markdown]
# ## Visualization of Results

# %%
movie,r1,support=[],[],[]
for result in results:
    movie.append(tuple(result[2][0][0])[0])
    r1.append(tuple(result[2][0][1])[0])
    support.append(result[1])

# %%
columns=list(zip(movie,r1,support))

# %% [markdown]
# Converting into dataframe

# %%
result_df=pd.DataFrame(columns)
result_df.columns=['Movie','Recommendation','Support']
result_df
# Out:
#                                 Movie           Recommendation  Support
# 0                                2012          Children of Men    0.005
# 1                          Fight Club           22 Jump Street    0.003
# 2                                 300           Jurassic World    0.005
# 3                                 300      The Bourne Identity    0.005
# 4                                 300                    U-571    0.005
# ...                               ...                      ...      ...
# 1062                       The Hunted           The Internship    0.003
# 1063  The Girl with the Dragon Tattoo          We Bought a Zoo    0.003
# 1064  The Girl with the Dragon Tattoo          The Last Castle    0.003
# 1065                          The Kid    The Road to El Dorado    0.003
# 1066                      The Kingdom  xXx: State of the Union    0.003
#
# [1067 rows x 3 columns]

# %% [markdown]
# Diurutkan berdasarkan "Support"

# %%
result_df=result_df.sort_values('Support',ascending=False)
result_df
# Out:
#                                  Film yang dipilih  \
# 36       Star Wars: Episode I - The Phantom Menace
# 39                        The Amazing Spider-Man 2
# 37    Star Wars: Episode II - Attack of the Clones
# 34                                     End of Days
# 38    Star Wars: Episode III - Revenge of the Sith
# ...                                            ...
# 509                                     Grindhouse
# 510                                     Grindhouse
# 511                                         Avatar
# 512                                         Avatar
# 1066                                   The Kingdom
#
#                                        Rekomendasi  Support
# 36                                          Avatar    0.032
# 39                                          Avatar    0.031
# 37                                          Avatar    0.030
# 34                                          Avatar    0.028
# 38                                          Avatar    0.027
# ...                                            ...      ...
# 509   Star Wars: Episode III - Revenge of the Sith    0.003
# 510                              The Peanuts Movie    0.003
# 511                                      Hereafter    0.003
# 512   Harry Potter and the Deathly Hallows: Part I    0.003
# 1066                       xXx: State of the Union    0.003
#
# [1067 rows x 3 columns]
