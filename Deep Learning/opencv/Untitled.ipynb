# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
import pytesseract
"C:\Program Files\Tesseract-OCR\tesseract.exe"
# Out:
# 'C:\\Program Files\\Tesseract-OCR\tesseract.exe'

# %%
# import os
# print("PYTHONPATH:", os.environ.get('PYTHONPATH'))
# print("PATH:", os.environ.get('PATH'))

# %%
img = cv2.imread("C:/Users/Shubham/Downloads/BingWallpaper (1).jpg",1)
print("Image dimension:", img.shape)
img = cv2.line(img,(0,0),(1000,1000),(255,0,0),10)
# cv2.imshow("ImageName",img)
cv2.circle(img,(500,500),100,(0,0,255),-1)
cv2.rectangle(img,(500,550),(1000,1050),(0,255,0),10)
plt.imshow(img, cmap='gray')
# 
# cv2.waitKey(5000)
# cv2.destroyAllWindows()
# Out:
# Image dimension: (1200, 1920, 3)
